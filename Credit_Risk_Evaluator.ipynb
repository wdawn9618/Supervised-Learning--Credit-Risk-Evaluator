# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score
from imblearn.metrics import classification_report_imbalanced
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.utils.random import sample_without_replacement
from sklearn.utils import resample

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
train_df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0     7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1    40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2    11000.0    0.2055       294.81           RENT     45000.0
# 3     4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4    14000.0    0.1797       505.93       MORTGAGE     43000.0
#
#   verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Not Verified          n  28.62          0.0             2.0  ...
# 1     Source Verified          n  11.72          2.0             0.0  ...
# 2            Verified          n  37.25          1.0             3.0  ...
# 3        Not Verified          n  42.89          1.0             0.0  ...
# 4     Source Verified          n  22.16          1.0             0.0  ...
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# ...

# %%
test_df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    40000.0    0.1033       856.40           RENT    128700.0
# 1    24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2    13500.0    0.1430       316.23            OWN     60000.0
# 3    10625.0    0.1774       268.31           RENT     60000.0
# 4     6375.0    0.1862       232.46           RENT     60000.0
#
#   verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0     Source Verified          n  12.47          0.0             1.0  ...
# 1        Not Verified          n  15.05          0.0             1.0  ...
# 2        Not Verified          n  28.72          0.0             0.0  ...
# 3            Verified          n  15.70          0.0             4.0  ...
# 4     Source Verified          n  35.50          0.0             0.0  ...
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# ...

# %%
# Convert categorical data to numeric and separate target feature for training data
X = train_df.drop('target', axis = 1)
y = train_df['target']
X_training= X
y_training = y

# %%
X_testing =test_df.drop('target', axis = 1)
y_testing = test_df['target']

# %%
X_training = pd.get_dummies(X_training)
X_testing = pd.get_dummies(X_testing)

# %%
X_training.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0     7000.0    0.1894       256.38     75000.0  28.62          0.0
# 1    40000.0    0.1614       975.71    102000.0  11.72          2.0
# 2    11000.0    0.2055       294.81     45000.0  37.25          1.0
# 3     4000.0    0.1612       140.87     38000.0  42.89          1.0
# 4    14000.0    0.1797       505.93     43000.0  22.16          1.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             2.0      20.0      0.0    40414.0  ...
# 1             0.0      10.0      0.0    43531.0  ...
# 2             3.0      23.0      0.0     8242.0  ...
# 3             0.0       7.0      0.0    12767.0  ...
# 4             0.0      22.0      0.0    11182.0  ...
#
#    verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                             0             1                      1
# 1                             0             1                      0
# ...

# %%
X_training.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
X_testing.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    40000.0    0.1033       856.40    128700.0  12.47          0.0
# 1    24450.0    0.1430       572.72     44574.0  15.05          0.0
# 2    13500.0    0.1430       316.23     60000.0  28.72          0.0
# 3    10625.0    0.1774       268.31     60000.0  15.70          0.0
# 4     6375.0    0.1862       232.46     60000.0  35.50          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             1.0       8.0      0.0    38113.0  ...
# 1             1.0       6.0      0.0     1665.0  ...
# 2             0.0       8.0      0.0    13857.0  ...
# 3             4.0      17.0      0.0     6216.0  ...
# 4             0.0      13.0      0.0    12681.0  ...
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                    1                             0
# 1                                    0                             0
# ...

# %%
X_testing.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
#add null column
X_testing['debt_settlement_flag_Y'] = '0'
X_testing.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    40000.0    0.1033       856.40    128700.0  12.47          0.0
# 1    24450.0    0.1430       572.72     44574.0  15.05          0.0
# 2    13500.0    0.1430       316.23     60000.0  28.72          0.0
# 3    10625.0    0.1774       268.31     60000.0  15.70          0.0
# 4     6375.0    0.1862       232.46     60000.0  35.50          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             1.0       8.0      0.0    38113.0  ...
# 1             1.0       6.0      0.0     1665.0  ...
# 2             0.0       8.0      0.0    13857.0  ...
# 3             4.0      17.0      0.0     6216.0  ...
# 4             0.0      13.0      0.0    12681.0  ...
#
#    verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                             0             1                      0
# 1                             0             1                      0
# ...

# %%
#Prediction for modeling - My prediction is the Logistic Regression model will be a better predictor as it performs better when
#the noise variables are less than the number of explanatory variables.  The variables impacting the target in the dataset are few.

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_training, y_training)
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_training, y_training)}")
print(f"Testing Data Score: {classifier.score(X_testing, y_testing)}")
# Out:
# Training Data Score: 0.6544334975369458
# Testing Data Score: 0.5089323692045938

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_training, y_training)
print(f'Training Score: {clf.score(X_training, y_training)}')
print(f'Testing Score: {clf.score(X_testing, y_testing)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.646958740961293

# %%
#Scaling the data should improve the accuracy although it may not, given this is not a distance-based method.

# %%
# Scale the data
scaler = StandardScaler().fit(X_training)
X_train_scaled = scaler.transform(X_training)
X_test_scaled = scaler.transform(X_testing)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
clf = LogisticRegression().fit(X_train_scaled, y_training)
print(f'Training Score: {clf.score(X_train_scaled, y_training)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_testing)}')
# Out:
# Training Score: 0.710919540229885
# Testing Score: 0.7598894087622289

# %%
# The logistic regression model after scaling had better accuracy over unscaled data. As I predicted the Logistic Regression Model
# held a better accuracy rate vs. the Random Forest Model.

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_training)
print(f'Training Score: {clf.score(X_train_scaled, y_training)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_testing)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6480221182475542

# %%
# The scoring on the Random Forest Model on the scaled and unscaled data was roughly the same.  There was a great diversity in 
#scoring between the scaled and unscaled data in Logistic Regression modeling.
